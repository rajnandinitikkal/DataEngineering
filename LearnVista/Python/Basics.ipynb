# %%
print(12)
# Out:
# 12

# %%
def example(a):
    a = a+ '2'
    a = a * 2
    return a
example("hello")
# Out:
# 'hello2hello2'

# %%
print('tom\ndick\nharry')
# Out:
# tom
# dick
# harry

# %%
apple = mango
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 apple = mango
#
# NameError: name 'mango' is not defined

# %%
print('hello' + '-' + 'how' + '-' + 'are' + '-' + 'you' )
# Out:
# hello-how-are-you

# %%
my_str = "hello"
print(my_str[:2])
# Out:
# he

# %%
complex(3,1)
# Out:
# (3+1j)

# %%
round(0.5) - round(-0.5)
# Out:
# 0

# %%
~4
# Out:
# -5

# %%
k = 3 + 3i

# %%
0.1 + 0.2 == 0.3
# Out:
# False

# %%
~~~~~~5
# Out:
# 5

# %%
float('inf')
print(type(inf))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 2
#       1 float('inf')
# ----> 2 print(type(inf))
#
# NameError: name 'inf' is not defined

# %%
float("52"+'72')
# Out:
# 5272.0

# %%
float('11+35')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 float('11+35')
#
# ValueError: could not convert string to float: '11+35'

# %%
print(type(inf))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 print(type(inf))
#
# NameError: name 'inf' is not defined

# %%
3 ** 4
# Out:
# 81

# %%
3 ^ 4
# Out:
# 7

# %%
24//6%3, 24//4//2
# Out:
# (1, 3)

# %%
int(43.55+2/2)
# Out:
# 44

# %%
2+9*((3*12)-8)/10
# Out:
# 27.2

# %%
4 + 3 % 5
# Out:
# 7

# %%
float(4+ int(2.39)%2)
# Out:
# 4.0

# %%
2**2**3
# Out:
# 256

# %%
(2**2)**3
# Out:
# 64

# %%
# 3.4 + 4.6
# 7.9 * 6.3
# 1.7 % 2
4.7 - 1.5
# Out:
# 3.2

# %%
(2**3)**2
# Out:
# 64

# %%
2+4.00 , 2**4.0
# Out:
# (6.0, 16.0)

# %%
# 4/(3*(2-1))
4/3*(2-1)
# Out:
# 1.3333333333333333

# %%
(4.00/(2.0+2.0))
# Out:
# 1.0

# %%
16 % 15 // 16
# Out:
# 0

# %%
4+2**5//10
# Out:
# 7

# %%
# float('10.8')
# int('10')
# float('10')
int('10.8')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[49], line 4
#       1 # float('10.8')
#       2 # int('10')
#       3 # float('10')
# ----> 4 int('10.8')
#
# ValueError: invalid literal for int() with base 10: '10.8'

# %%
8/4/2, 8/(4/2)
# Out:
# (1.0, 4.0)

# %%
float(22/3+3/3)
# Out:
# 8.333333333333332

# %%
a = 10
b = 20
a = a^b
b = a^b
a = a^b
print(a,b)
# Out:
# 20 10

# %%
a << 2
# Out:
# 80

# %%
a << 4
# Out:
# 320

# %%
a >> 2
# Out:
# 5

# %%
a >> 4
# Out:
# 1

# %%
bin(10-2)+bin(12^4)
# Out:
# '0b10000b1000'

# %%
bin(0x8)
# Out:
# '0b1000'

# %%
a = 10
b = 4
print("a | b =", a|b)
# Out:
# a | b = 14

# %%
~100
# Out:
# -101

# %%
bin(29)
# Out:
# '0b11101'

# %%
int('1111',2)
# Out:
# 15

# %%
4^12
# Out:
# 8

# %%
dir(bool)
# Out:
# ['__abs__',
#  '__add__',
#  '__and__',
#  '__bool__',
#  '__ceil__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__float__',
#  '__floor__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__index__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__le__',
#  '__lshift__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__or__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__rdivmod__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rlshift__',
#  '__rmod__',
#  '__rmul__',
#  '__ror__',
#  '__round__',
#  '__rpow__',
#  '__rrshift__',
#  '__rshift__',
#  '__rsub__',
#  '__rtruediv__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__trunc__',
#  '__xor__',
# ...

# %%
x = 15
y = 12
x & y
# Out:
# 12

# %%
0x35 | 0x75
# Out:
# 117

# %%
4 >> 2
# Out:
# 1

# %%
bin(-44)
# Out:
# '-0b101100'

# %%
bool('False')
# bool()
# Out:
# True

# %%
['f','t'][bool('spam')]
# Out:
# 't'

# %%
class Truth:
    pass
x = Truth()
bool(x)
# Out:
# True

# %%
not(-6<0 or -6>10)
# Out:
# False

# %%
-6>=0 and -6<=0
# Out:
# False

# %%
not(-6<10 or -6==10)
# Out:
# False

# %%
not(-6>10 or -6==10)
# Out:
# True

# %%
not(3>4)
# Out:
# True

# %%
not(1&1)
# Out:
# False

# %%
if(9<0) and (0<-9):
    print("hello")
elif(9>0) or False:
    print("good")
else:
    ("bad")
# Out:
# good

# %%
l = [1,0,2,0,"hello", '',[]]
list(filter(bool, l))
# Out:
# [1, 2, 'hello']

# %%
[] or {}
{} or []
# Out:
# []

# %%
['hello','morning'][bool('')]
# Out:
# 'hello'

# %%
not(10<20) and not(10>30)
# Out:
# False
